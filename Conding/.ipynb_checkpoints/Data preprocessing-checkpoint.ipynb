# %%
#本脚本主要实现内容为基于tripadvisor澳门地区酒店数据图像识别内容之后文本内容的数据预处理部分

# %%
#　导入必要的包
import csv
import numpy as np
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster,cut_tree,cophenet,inconsistent
import scipy.cluster.hierarchy as sch
from matplotlib import pyplot as plt
from matplotlib.pyplot import xticks
import pandas as pd
from scipy.spatial import distance
from itertools import groupby #itertool还包含有其他很多函数，比如将多个list联合起来
import json
from sklearn.metrics.pairwise import euclidean_distances
import re
from orangecontrib.associate.fpgrowth import * 
from collections import Counter

# %%
'''
函数名：读数据
输入：json数据的路径
输出：每张图片用list数据存储的label集，每个图片label的评分集，以及每个图片的url
描述：该函数实现从文件中读取json数据文件，并分别解析出label集，评分集，以及url集
'''
def loadjson_label(path):
    with open (path,'rb') as json_data:
        data = json.load(json_data)
    labels = []
    
    #打印所有的labels
    for i in data:
        labels.append(i[:-1])
    classes = []
    for i in labels:
        temp = []
        for j in i:
            c = list(j[0].values())
            temp.append(c[0])
        classes.append(temp)
    
    # 打印所有的score
    score = []
    for i in labels:
        temp = []
        for j in i:
            c = list(j[1].values())
            temp.append(c[0])
        score.append(temp)

    
    #打印所有的urls
    urls = []
    for i in data:
        urls.append(list(i[-1].values())[0])    
    return classes, score, urls

# %%
# 读数据face
def loadjson_face(path):
    with open (path,'rb') as json_data:
        data = json.load(json_data)
    data_with_face = []
    for i in data:
        if len(i)!=1:
            data_with_face.append(i)
    rate = len(data_with_face)/len(data)
#     print ("识别出来脸总共：",len(data_with_face))
#     print ("总数据：",len(data))
    return data,data_with_face,rate

# %%
# 读数据color
def loadjson_color(path):
    with open (path,'rb') as json_data:
        data = json.load(json_data)
    labels = []
    # #打印所有的了labels
    for i in data:
        labels.append(i[:-1])
    temp = []
    for i in labels:
        temp_t = []
        for j in i:
            temp_t.append(j[:4])
        temp.append(temp_t)

    urls = []
    for i in data:
        urls.append(i[-1])

    datasets = []
    for i in range(0,len(temp)):
        datasets.append(list(temp[i])+list(urls[i].values()))
        
    return datasets

# %%
# 读label
print('====================================官方数据集label识别结果=======================================')
official_labelset_five,official_score_five, official_urls_five = loadjson_label('dataset\official\google\label\\five.json')
print('五星级酒店图片总共:',len(official_labelset_five))
official_labelset_four,official_score_four, official_urls_four = loadjson_label('dataset\official\google\label\\four.json')
print ('四星级酒店图片总共:',len(official_labelset_four))
official_labelset_three,official_score_three, official_urls_three = loadjson_label('dataset\official\google\label\\three.json')
print ('三星级酒店图片总共:',len(official_labelset_three))
official_labelset_two,official_score_two, official_urls_two = loadjson_label('dataset\official\google\label\\two.json')
print ('二星级酒店图片总共:',len(official_labelset_two))
print('总数据量：',len(official_labelset_five)+len(official_labelset_four)+len(official_labelset_three)+len(official_labelset_two))

# 读color
print('=====================================官方数据集color识别结果========================================')
official_colorset_five = loadjson_color('dataset\official\google\color\\five.json')
print('五星级酒店可识别颜色图片总数：',len(official_colorset_five))
official_colorset_four = loadjson_color('dataset\official\google\color\\four.json')
print('四星级酒店可识别颜色图片总数：',len(official_colorset_four))
official_colorset_three= loadjson_color('dataset\official\google\color\\three.json')
print('三星级酒店可识别颜色图片总数：',len(official_colorset_three))
official_colorset_two= loadjson_color('dataset\official\google\color\\two.json')
print('二星级酒店可识别颜色图片总数：',len(official_colorset_two))
print ('总数据量：',len(official_colorset_five)+len(official_colorset_four)+len(official_colorset_three)+len(official_colorset_two))

# 读face
print ('======================================官方数据集face识别结果=======================================')
#其中faceset_five表示五星级酒店总数据，face_five表示识别出来脸的图片集，rate_five表示评分
official_faceset_five,official_face_five,official_rate_five = loadjson_face('dataset\official\google\\face\\five.json')
print('五星级酒店识别出来脸的图片：',len(official_face_five))
official_faceset_four,official_face_four,official_rate_four = loadjson_face('dataset\official\google\\face\\four.json')
print('四星级酒店识别出来脸的图片：',len(official_face_four))
official_faceset_three,official_face_three,official_rate_three = loadjson_face('dataset\official\google\\face\\three.json')
print('三星级酒店识别出来脸的图片：',len(official_face_three))
official_faceset_two,official_face_two,official_rate_two = loadjson_face('dataset\official\google\\face\\two.json')
print('二星级酒店识别出来脸的图片：',len(official_face_two))
print ('总共识别出来脸的图片数据量：',len(official_face_five)+len(official_face_four)+len(official_face_three)+len(official_face_two))
# Out:
# ====================================官方数据集label识别结果=======================================
# 五星级酒店图片总共: 1221
# 四星级酒店图片总共: 849
# 三星级酒店图片总共: 222
# 二星级酒店图片总共: 105
# 总数据量： 2397
# =====================================官方数据集color识别结果========================================
# 五星级酒店可识别颜色图片总数： 1221
# 四星级酒店可识别颜色图片总数： 849
# 三星级酒店可识别颜色图片总数： 222
# 二星级酒店可识别颜色图片总数： 105
# 总数据量： 2397
# ======================================官方数据集face识别结果=======================================
# 五星级酒店识别出来脸的图片： 26
# 四星级酒店识别出来脸的图片： 11
# 三星级酒店识别出来脸的图片： 0
# 二星级酒店识别出来脸的图片： 0
# 总共识别出来脸的图片数据量： 37

# %%
# 读label
print('====================================游客数据集label识别结果=======================================')
traveler_labelset_five,traveler_score_five, traveler_urls_five = loadjson_label('dataset\\travelers\google\label\\five.json')
print('五星级酒店图片总共:',len(traveler_labelset_five))
traveler_labelset_four,traveler_score_four, traveler_urls_four = loadjson_label('dataset\\travelers\google\label\\four.json')
print ('四星级酒店图片总共:',len(traveler_labelset_four))
traveler_labelset_three,traveler_score_three, traveler_urls_three = loadjson_label('dataset\\travelers\google\label\\three.json')
print ('三星级酒店图片总共:',len(traveler_labelset_three))
traveler_labelset_two,traveler_score_two, traveler_urls_two = loadjson_label('dataset\\travelers\google\label\\two.json')
print ('二星级酒店图片总共:',len(traveler_labelset_two))
print('总数据量：',len(traveler_labelset_five)+len(traveler_labelset_four)+len(traveler_labelset_three)+len(traveler_labelset_two))

# 读color
print('=====================================游客数据集color识别结果========================================')
traveler_colorset_five = loadjson_color('dataset\\travelers\google\color\\five.json')
print('五星级酒店可识别颜色图片总数：',len(traveler_colorset_five))
traveler_colorset_four = loadjson_color('dataset\\travelers\google\color\\four.json')
print('四星级酒店可识别颜色图片总数：',len(traveler_colorset_four))
traveler_colorset_three= loadjson_color('dataset\\travelers\google\color\\three.json')
print('三星级酒店可识别颜色图片总数：',len(traveler_colorset_three))
traveler_colorset_two= loadjson_color('dataset\\travelers\google\color\\two.json')
print('二星级酒店可识别颜色图片总数：',len(traveler_colorset_two))
print ('总数据量：',len(traveler_colorset_five)+len(traveler_colorset_four)+len(traveler_colorset_three)+len(traveler_colorset_two))

# 读face
print ('======================================游客数据集face识别结果=======================================')
#其中faceset_five表示五星级酒店总数据，face_five表示识别出来脸的图片集，rate_five表示评分
traveler_faceset_five,traveler_face_five,traveler_rate_five = loadjson_face('dataset\\travelers\google\\face\\five.json')
print('五星级酒店识别出来脸的图片：',len(traveler_face_five))
traveler_faceset_four,traveler_face_four,traveler_rate_four = loadjson_face('dataset\\travelers\google\\face\\four.json')
print('四星级酒店识别出来脸的图片：',len(traveler_face_four))
traveler_faceset_three,traveler_face_three,traveler_rate_three = loadjson_face('dataset\\travelers\google\\face\\three.json')
print('三星级酒店识别出来脸的图片：',len(traveler_face_three))
traveler_faceset_two,traveler_face_two,traveler_rate_two = loadjson_face('dataset\\travelers\google\\face\\two.json')
print('二星级酒店识别出来脸的图片：',len(traveler_face_two))
print ('总共识别出来脸的图片数据量：',len(traveler_face_five)+len(traveler_face_four)+len(traveler_face_three)+len(traveler_face_two))
# Out:
# ====================================游客数据集label识别结果=======================================
# 五星级酒店图片总共: 32023
# 四星级酒店图片总共: 15249
# 三星级酒店图片总共: 3627
# 二星级酒店图片总共: 517
# 总数据量： 51416
# =====================================游客数据集color识别结果========================================
# 五星级酒店可识别颜色图片总数： 32023
# 四星级酒店可识别颜色图片总数： 15249
# 三星级酒店可识别颜色图片总数： 3627
# 二星级酒店可识别颜色图片总数： 517
# 总数据量： 51416
# ======================================游客数据集face识别结果=======================================
# 五星级酒店识别出来脸的图片： 734
# 四星级酒店识别出来脸的图片： 309
# 三星级酒店识别出来脸的图片： 37
# 二星级酒店识别出来脸的图片： 6
# 总共识别出来脸的图片数据量： 1086

# %%
'''
函数名：数据预处理
输入：label集，url
输出：经过处理的label集，并将url并进去
描述：通过该函数将获取到的数据集进行预处理。1.去掉空格，2.去掉括号，3.将url添加上。
'''
def preprocessing(labelset,urls):
    i=0
    for labels in labelset:
        labels.append(urls[i])
        i+=1
    sets_ini = []
    for i in labelset:
        inter_sets = []
        for j in i:
            j = j.replace(' ','')                          # 去掉空格
            inter_sets.append(re.sub('\((.*?\))', '', j))  # 去掉括号
        sets_ini.append(inter_sets)
    return sets_ini

# %%
#　对数据集进行预处理
print ('=======================================官方数据集预处理===============================')
official_five_ini = preprocessing(official_labelset_five,official_urls_five)
print ("五星级酒店官方图片数据集个数 = ", len (official_five_ini))
official_four_ini = preprocessing(official_labelset_four,official_urls_four)
print ("四星级酒店官方图片数据集个数 = ", len (official_four_ini))
official_three_ini = preprocessing(official_labelset_three,official_urls_three)
print ("三星级酒店官方图片数据集个数 = ", len (official_three_ini))
official_two_ini = preprocessing(official_labelset_two,official_urls_two)
print ("二星级酒店官方图片数据集个数 = ", len (official_two_ini))

print('========================================游客数据集预处理===============================')
traveler_five_ini = preprocessing(traveler_labelset_five,traveler_urls_five)
print ("五星级酒店游客图片数据集个数 = ", len (traveler_five_ini))
traveler_four_ini = preprocessing(traveler_labelset_four,traveler_urls_four)
print ("四星级酒店游客图片数据集个数 = ", len (traveler_four_ini))
traveler_three_ini = preprocessing(traveler_labelset_three,traveler_urls_three)
print ("三星级酒店游客图片数据集个数 = ", len (traveler_three_ini))
traveler_two_ini = preprocessing(traveler_labelset_two,traveler_urls_two)
print ("二星级酒店游客图片数据集个数 = ", len (traveler_two_ini))
# Out:
# =======================================官方数据集预处理===============================
# 五星级酒店官方图片数据集个数 =  1221
# 四星级酒店官方图片数据集个数 =  849
# 三星级酒店官方图片数据集个数 =  222
# 二星级酒店官方图片数据集个数 =  105
# ========================================游客数据集预处理===============================
# 五星级酒店游客图片数据集个数 =  32023
# 四星级酒店游客图片数据集个数 =  15249
# 三星级酒店游客图片数据集个数 =  3627
# 二星级酒店游客图片数据集个数 =  517

# %%
# 取出所有的label
'''
函数名：取出所有label并进行统计
输入：每个图片的label list
输出：每个数据集中的label集合，数据集label统计并排序之后的结果
描述：对之前的图片的label list中的label先取出来，然后进行统计每个label在整个数据集中出现的百分比
'''
def label_stat(sets_ini):
    all_sets = [] # 存放c不带url的数据集
    for i in sets_ini:
        all_sets.append(i[:-1])
    label_all = [] # 存放所有label
    for i in all_sets:
        for j in i:
            label_all.append(j)           
    #数据集长度定义
    length = len(all_sets)
    #数据集每个label计数
    c = Counter(label_all)
    stat_sets = []
    for i in c.items():
        stat_sets.append([i[0],round(i[1]/length,5)])
    # 数据集label 频率排序    
    n = len(stat_sets)
    for i in range(n-1):
        for j in range(n-i-1):
            if stat_sets[j][1]<stat_sets[j+1][1]:
                stat_sets[j],stat_sets[j+1] = stat_sets[j+1],stat_sets[j]
    return label_all, stat_sets

# %%
#official_label_all_five表示五星级酒店出现的标签，official_stat_five表示五星级酒店每个词以及这个词出现的频率
print('===============================官方数据集label统计=======================================')
official_label_all_five, official_stat_five = label_stat(official_five_ini)
print ("五星级酒店官方数据集label个数 = ",len(official_label_all_five))
official_label_all_four,official_stat_four = label_stat(official_four_ini)
print ("四星级酒店官方数据集label个数 = ",len(official_label_all_four))
official_label_all_three,official_stat_three = label_stat(official_three_ini)
print ("三星级酒店官方数据集label个数 = ",len(official_label_all_three))
official_label_all_two,official_stat_two = label_stat(official_two_ini)
print ("二星级酒店官方数据集label个数 = ",len(official_label_all_two))

print('==============================游客数据集label统计=======================================')
traveler_label_all_five, traveler_stat_five = label_stat(traveler_five_ini)
print ("五星级酒店游客数据集label个数 = ",len(traveler_label_all_five))
traveler_label_all_four,traveler_stat_four = label_stat(traveler_four_ini)
print ("四星级酒店游客数据集label个数 = ",len(traveler_label_all_four))
traveler_label_all_three,traveler_stat_three = label_stat(traveler_three_ini)
print ("三星级酒店游客数据集label个数 = ",len(traveler_label_all_three))
traveler_label_all_two,traveler_stat_two = label_stat(traveler_two_ini)
print ("二星级酒店游客数据集label个数 = ",len(traveler_label_all_two))
# Out:
# ===============================官方数据集label统计=======================================
# 五星级酒店官方数据集label个数 =  9863
# 四星级酒店官方数据集label个数 =  6952
# 三星级酒店官方数据集label个数 =  1754
# 二星级酒店官方数据集label个数 =  782
# ==============================游客数据集label统计=======================================
# 五星级酒店游客数据集label个数 =  251626
# 四星级酒店游客数据集label个数 =  119876
# 三星级酒店游客数据集label个数 =  28408
# 二星级酒店游客数据集label个数 =  4067

# %%
official_stat_five
# Out:
# [['interiordesign', 0.68223],
#  ['ceiling', 0.47993],
#  ['room', 0.38002],
#  ['realestate', 0.36446],
#  ['lobby', 0.33415],
#  ['suite', 0.30958],
#  ['estate', 0.21949],
#  ['livingroom', 0.19001],
#  ['hotel', 0.18182],
#  ['restaurant', 0.18182],
#  ['functionhall', 0.181],
#  ['property', 0.15561],
#  ['window', 0.1335],
#  ['floor', 0.13022],
#  ['flooring', 0.12531],
#  ['condominium', 0.12367],
#  ['wall', 0.09091],
#  ['bedroom', 0.08763],
#  ['building', 0.08026],
#  ['leisure', 0.07944],
#  ['table', 0.07371],
#  ['resort', 0.0688],
#  ['conferencehall', 0.06798],
#  ['landmark', 0.06552],
#  ['metropolitanarea', 0.0647],
#  ['home', 0.06224],
#  ['food', 0.05815],
#  ['diningroom', 0.05651],
#  ['furniture', 0.05651],
#  ['city', 0.05569],
#  ['ballroom', 0.05569],
#  ['penthouseapartment', 0.05487],
#  ['metropolis', 0.05324],
#  ['hall', 0.05324],
#  ['ceremony', 0.05324],
#  ['apartment', 0.0516],
#  ['swimmingpool', 0.0516],
#  ['dish', 0.0516],
#  ['touristattraction', 0.04996],
#  ['bathroom', 0.04996],
#  ['banquet', 0.04996],
#  ['lighting', 0.04914],
#  ['cuisine', 0.04914],
#  ['sky', 0.04505],
#  ['architecture', 0.04423],
#  ['tourism', 0.04423],
#  ['café', 0.04341],
#  ['mixeduse', 0.04095],
#  ['weddingreception', 0.03686],
#  ['daylighting', 0.03522],
#  ['windowtreatment', 0.0344],
#  ['water', 0.03194],
#  ['bedframe', 0.02948],
#  ['buffet', 0.02867],
#  ['recipe', 0.02867],
#  ['skyscraper', 0.02703],
#  ['structure', 0.02703],
#  ['vacation', 0.02703],
#  ['floristry', 0.02621],
#  ['tableware', 0.02457],
#  ['meal', 0.02293],
#  ['flower', 0.02211],
#  ['windowcovering', 0.02211],
#  ['urbanarea', 0.02129],
#  ['asianfood', 0.02129],
#  ['facade', 0.02129],
#  ['tree', 0.02048],
#  ['leisurecentre', 0.02048],
#  ['plaza', 0.01966],
#  ['waterfeature', 0.01802],
#  ['brunch', 0.01802],
#  ['resorttown', 0.01802],
#  ['animalsourcefoods', 0.01802],
#  ['cityscape', 0.0172],
#  ['night', 0.0172],
#  ['purple', 0.0172],
#  ['centrepiece', 0.0172],
#  ['reflection', 0.01638],
#  ['recreation', 0.01638],
#  ['aisle', 0.01638],
#  ['glass', 0.01638],
#  ['shoppingmall', 0.01556],
#  ['product', 0.01556],
#  ['conventioncenter', 0.01556],
#  ['towerblock', 0.01474],
#  ['commercialbuilding', 0.01474],
#  ['flowerarranging', 0.01474],
#  ['drink', 0.0131],
#  ['curtain', 0.0131],
#  ['blue', 0.01229],
#  ['girl', 0.01229],
#  ['gym', 0.01229],
#  ['wood', 0.01147],
#  ['column', 0.01147],
#  ['plant', 0.01065],
#  ['theatre', 0.01065],
#  ['palace', 0.01065],
#  ['outdoorstructure', 0.01065],
#  ['corporateheadquarters', 0.00983],
#  ['palmtree', 0.00983],
#  ['fun', 0.00983],
#  ['classicalarchitecture', 0.00983],
#  ['meat', 0.00983],
#  ['bar', 0.00901],
#  ['comfort', 0.00901],
#  ['computerwallpaper', 0.00901],
#  ['waterpark', 0.00901],
#  ['seafood', 0.00901],
#  ['dessert', 0.00901],
#  ['skyline', 0.00819],
#  ['sportvenue', 0.00819],
#  ['symmetry', 0.00819],
#  ['arecales', 0.00819],
#  ['breakfast', 0.00819],
#  ['appetizer', 0.00819],
#  ['event', 0.00819],
#  ['floraldesign', 0.00819],
#  ["bird'seyeview", 0.00737],
#  ['vegetarianfood', 0.00737],
#  ['lightfixture', 0.00737],
#  ['light', 0.00737],
#  ['auditorium', 0.00737],
#  ['tile', 0.00737],
#  ['waterway', 0.00655],
#  ['tower', 0.00655],
#  ['daytime', 0.00655],
#  ['cocktail', 0.00655],
#  ['mansion', 0.00655],
#  ['cabinetry', 0.00655],
#  ['tradition', 0.00655],
#  ['garnish', 0.00655],
#  ['flowerbouquet', 0.00655],
#  ['roof', 0.00573],
#  ['darkness', 0.00573],
#  ['loft', 0.00573],
#  ['retail', 0.00573],
#  ['cocktailgarnish', 0.00573],
#  ['nonalcoholicbeverage', 0.00573],
#  ['historicsite', 0.00573],
#  ['chinesefood', 0.00573],
#  ['cup', 0.00573],
#  ['cosmetics', 0.00573],
#  ['beauty', 0.00573],
#  ['modernart', 0.00573],
#  ['exercisemachine', 0.00573],
#  ['art', 0.00573],
#  ['decor', 0.00573],
#  ['fingerfood', 0.00573],
#  ['cook', 0.00573],
#  ['font', 0.00491],
#  ['fastfoodrestaurant', 0.00491],
#  ['grass', 0.00491],
#  ['woodflooring', 0.00491],
#  ['urbandesign', 0.00491],
#  ['waterresources', 0.00491],
#  ['material', 0.00491],
#  ['chineserestaurant', 0.00491],
#  ['arch', 0.00491],
#  ['placeofworship', 0.00491],
#  ['sitting', 0.00491],
#  ['chandelier', 0.00491],
#  ['sink', 0.00491],
#  ['wedding', 0.00491],
#  ['chef', 0.00491],
#  ['friedfood', 0.0041],
#  ['classiccocktail', 0.0041],
#  ['cafeteria', 0.0041],
#  ['garden', 0.0041],
#  ['bathtub', 0.0041],
#  ['graphics', 0.0041],
#  ['villa', 0.0041],
#  ['thaifood', 0.0041],
#  ['wallpaper', 0.0041],
#  ['coffeecup', 0.0041],
#  ['stilllifephotography', 0.0041],
#  ['drinkware', 0.0041],
#  ['pink', 0.0041],
#  ['chapel', 0.0041],
#  ['hardwood', 0.0041],
#  ['thermae', 0.0041],
#  ['countertop', 0.0041],
#  ['stairs', 0.0041],
#  ['physicalfitness', 0.0041],
#  ['roasting', 0.0041],
#  ['cooking', 0.0041],
#  ['town', 0.00328],
#  ['sidedish', 0.00328],
#  ['landscape', 0.00328],
#  ['tavern', 0.00328],
#  ['text', 0.00328],
#  ['brand', 0.00328],
#  ['neighbourhood', 0.00328],
#  ['amusementpark', 0.00328],
#  ['watercourse', 0.00328],
#  ['porcelain', 0.00328],
#  ['serveware', 0.00328],
#  ['bed', 0.00328],
#  ['shelf', 0.00328],
#  ['waterbird', 0.00328],
#  ['ducksgeeseandswans', 0.00328],
#  ['duck', 0.00328],
#  ['beak', 0.00328],
#  ['bird', 0.00328],
#  ['performingartscenter', 0.00328],
#  ['office', 0.00328],
#  ['spa', 0.00328],
#  ['kitchen', 0.00328],
#  ['shrine', 0.00328],
#  ['arcade', 0.00328],
#  ['house', 0.00328],
#  ['shade', 0.00328],
#  ['dress', 0.00328],
#  ['weddingdress', 0.00328],
#  ['bride', 0.00328],
#  ['shoulder', 0.00328],
#  ['shelving', 0.00328],
#  ['plumbingfixture', 0.00328],
#  ['door', 0.00328],
#  ['kobebeef', 0.00328],
#  ['chiefcook', 0.00328],
#  ['landscapelighting', 0.00246],
#  ['aerialphotography', 0.00246],
#  ['world', 0.00246],
#  ['chair', 0.00246],
#  ['couch', 0.00246],
#  ['botanicalgarden', 0.00246],
#  ['sea', 0.00246],
#  ['travel', 0.00246],
#  ['medievalarchitecture', 0.00246],
#  ['ancientrome', 0.00246],
#  ['pub', 0.00246],
#  ['downtown', 0.00246],
#  ['logo', 0.00246],
#  ['line', 0.00246],
#  ['residentialarea', 0.00246],
#  ['soup', 0.00246],
#  ['coffee', 0.00246],
#  ['displaydevice', 0.00246],
#  ['masonjar', 0.00246],
#  ['shanghaifood', 0.00246],
#  ['swimwear', 0.00246],
#  ['blackhair', 0.00246],
#  ['photoshoot', 0.00246],
#  ['carpet', 0.00246],
#  ['casino', 0.00246],
#  ['fountain', 0.00246],
#  ['design', 0.00246],
#  ['temple', 0.00246],
#  ['recreationroom', 0.00246],
#  ['painting', 0.00246],
#  ['lunch', 0.00246],
#  ['mattress', 0.00246],
#  ['textile', 0.00246],
#  ['pattern', 0.00246],
#  ['photograph', 0.00246],
#  ['photography', 0.00246],
#  ['gown', 0.00246],
#  ['bridalclothing', 0.00246],
#  ['gazebo', 0.00246],
#  ['backyard', 0.00246],
#  ['thanksgivingdinner', 0.00246],
#  ['hendl', 0.00246],
#  ['dishware', 0.00246],
#  ['stemware', 0.00246],
#  ['liqueur', 0.00246],
#  ['green', 0.00246],
#  ['alcoholicbeverage', 0.00246],
#  ['streetfood', 0.00246],
#  ['cookwareandbakeware', 0.00246],
#  ['winecocktail', 0.00246],
#  ['organism', 0.00164],
#  ['luxuryvehicle', 0.00164],
#  ['space', 0.00164],
#  ['airportterminal', 0.00164],
#  ['daiquiri', 0.00164],
#  ['shopping', 0.00164],
#  ['outletstore', 0.00164],
#  ['car', 0.00164],
#  ['evening', 0.00164],
#  ['hotelmanager', 0.00164],
#  ['nationalhistoriclandmark', 0.00164],
#  ['coffeehouse', 0.00164],
#  ['magenta', 0.00164],
#  ['park', 0.00164],
#  ['coastalandoceaniclandforms', 0.00164],
#  ['stew', 0.00164],
#  ['hotpot', 0.00164],
#  ['europeanfood', 0.00164],
#  ['ceramic', 0.00164],
#  ['saucer', 0.00164],
#  ['espresso', 0.00164],
#  ['teddybear', 0.00164],
#  ['toy', 0.00164],
#  ['stuffedtoy', 0.00164],
#  ['snout', 0.00164],
#  ['bodyjewelry', 0.00164],
#  ['figurine', 0.00164],
#  ['closeup', 0.00164],
#  ['technology', 0.00164],
#  ['electronicdevice', 0.00164],
#  ['angle', 0.00164],
#  ['pâtisserie', 0.00164],
#  ['bakery', 0.00164],
#  ['longhair', 0.00164],
#  ['massage', 0.00164],
#  ['stage', 0.00164],
#  ['jacuzzi', 0.00164],
#  ['advertising', 0.00164],
#  ['stainedglass', 0.00164],
#  ['christmasdecoration', 0.00164],
#  ['statue', 0.00164],
#  ['pool', 0.00164],
#  ['molding', 0.00164],
#  ['bedsheet', 0.00164],
#  ['duvetcover', 0.00164],
#  ['synagogue', 0.00164],
#  ['muscle', 0.00164],
#  ['balcony', 0.00164],
#  ['japanesecuisine', 0.00164],
#  ['seafoodboil', 0.00164],
#  ['grillades', 0.00164],
#  ['lobster', 0.00164],
#  ['sashimi', 0.00164],
#  ['icecream', 0.00164],
#  ['thanksgiving', 0.00164],
#  ['roastgoose', 0.00164],
#  ['turkeymeat', 0.00164],
#  ['plate', 0.00164],
#  ['oyster', 0.00164],
#  ['clamsoystersmusselsandscallops', 0.00164],
#  ['comfortfood', 0.00164],
#  ['wineglass', 0.00164],
#  ['entertainment', 0.00164],
#  ['windowblind', 0.00164],
#  ['reflectingpool', 0.00164],
#  ['exerciseequipment', 0.00164],
#  ['paint', 0.00164],
#  ['bookcase', 0.00164],
#  ['juice', 0.00164],
#  ['headquarters', 0.00164],
#  ['red', 0.00164],
#  ['toiletseat', 0.00164],
#  ['hacienda', 0.00164],
#  ['animalfat', 0.00164],
#  ['frozendessert', 0.00164],
#  ['sundae', 0.00164],
#  ['condiment', 0.00164],
#  ['rice', 0.00164],
#  ['commodity', 0.00164],
#  ['maitai', 0.00164],
#  ['stockphotography', 0.00164],
#  ['harveywallbanger', 0.00164],
#  ['townsquare', 0.00082],
#  ['song', 0.00082],
#  ['screenshot', 0.00082],
#  ['infrastructure', 0.00082],
#  ['majorelleblue', 0.00082],
#  ['publictransport', 0.00082],
#  ['tenniscourt', 0.00082],
#  ['yellow', 0.00082],
#  ['football', 0.00082],
#  ['net', 0.00082],
#  ['tennis', 0.00082],
#  ['tennisequipmentandsupplies', 0.00082],
#  ['ball', 0.00082],
#  ['falafel', 0.00082],
#  ['meatball', 0.00082],
#  ['arancini', 0.00082],
#  ['martini', 0.00082],
#  ['cosmopolitan', 0.00082],
#  ['bacardicocktail', 0.00082],
#  ['sexonthebeach', 0.00082],
#  ['foodcourt', 0.00082],
#  ['suit', 0.00082],
#  ['area', 0.00082],
#  ['sunlounger', 0.00082],
#  ['rock', 0.00082],
#  ['irishstew', 0.00082],
#  ['daube', 0.00082],
#  ['curry', 0.00082],
#  ['stilllife', 0.00082],
#  ['italianfood', 0.00082],
#  ['flowerpot', 0.00082],
#  ['smallappliance', 0.00082],
#  ['espressomachine', 0.00082],
#  ['coffeemaker', 0.00082],
#  ['keyboard', 0.00082],
#  ['friedchicken', 0.00082],
#  ['southeastasianfood', 0.00082],
#  ['summer', 0.00082],
#  ['honeymoon', 0.00082],
#  ['model', 0.00082],
#  ['fashionmodel', 0.00082],
#  ['gravureidol', 0.00082],
#  ['undergarment', 0.00082],
#  ['therapy', 0.00082],
#  ['snowman', 0.00082],
#  ['waterfowl', 0.00082],
#  ['nail', 0.00082],
#  ['industry', 0.00082],
#  ['cathedral', 0.00082],
#  ['tours', 0.00082],
#  ['laminateflooring', 0.00082],
#  ['receptionist', 0.00082],
#  ['ancientromanarchitecture', 0.00082],
#  ['ancienthistory', 0.00082],
#  ['romantemple', 0.00082],
#  ['displaywindow', 0.00082],
#  ['graphicdesign', 0.00082],
#  ['label', 0.00082],
#  ['amusementride', 0.00082],
#  ['carousel', 0.00082],
#  ['theatricalscenery', 0.00082],
#  ['orange', 0.00082],
#  ['eating', 0.00082],
#  ['supper', 0.00082],
#  ['baluster', 0.00082],
#  ['nature', 0.00082],
#  ['bodyofwater', 0.00082],
#  ['waterfall', 0.00082],
#  ['stream', 0.00082],
#  ['leg', 0.00082],
#  ['lightingaccessory', 0.00082],
#  ['cajunfood', 0.00082],
#  ['crabboil', 0.00082],
#  ['decapoda', 0.00082],
#  ['spaghetti', 0.00082],
#  ['instantcoffee', 0.00082],
#  ['caffeine', 0.00082],
#  ['flashphotography', 0.00082],
#  ['vehicle', 0.00082],
#  ['woman', 0.00082],
#  ['junkfood', 0.00082],
#  ['aioli', 0.00082],
#  ['platter', 0.00082],
#  ['play', 0.00082],
#  ['champagne', 0.00082],
#  ['wine', 0.00082],
#  ['localfood', 0.00082],
#  ['marriage', 0.00082],
#  ['gimbap', 0.00082],
#  ['billiardroom', 0.00082],
#  ['liquorstore', 0.00082],
#  ['weddingceremonysupply', 0.00082],
#  ['shrub', 0.00082],
#  ['black', 0.00082],
#  ['midnight', 0.00082],
#  ['rehearsaldinner', 0.00082],
#  ['physicalexercise', 0.00082],
#  ['handrail', 0.00082],
#  ['monument', 0.00082],
#  ['sculpture', 0.00082],
#  ['archaeologicalsite', 0.00082],
#  ['artexhibition', 0.00082],
#  ['artgallery', 0.00082],
#  ['mural', 0.00082],
#  ['exhibition', 0.00082],
#  ['courtyard', 0.00082],
#  ['clotheshanger', 0.00082],
#  ['wardrobe', 0.00082],
#  ['psychedelicart', 0.00082],
#  ['fractalart', 0.00082],
#  ['petitfour', 0.00082],
#  ['distilledbeverage', 0.00082],
#  ['cabin', 0.00082],
#  ['patio', 0.00082],
#  ['displaycase', 0.00082],
#  ['landscaping', 0.00082],
#  ['petal', 0.00082],
#  ['tablecloth', 0.00082],
#  ['desk', 0.00082],
#  ['tap', 0.00082],
#  ['bathroomaccessory', 0.00082],
#  ['bathroomcabinet', 0.00082],
#  ['lady', 0.00082],
#  ['smile', 0.00082],
#  ['brownhair', 0.00082],
#  ['whitecollarworker', 0.00082],
#  ['grilling', 0.00082],
#  ['steak', 0.00082],
#  ['barbecue', 0.00082],
#  ['barbecuegrill', 0.00082],
#  ['snack', 0.00082],
#  ['pastry', 0.00082],
#  ['marketplace', 0.00082],
#  ['culinaryart', 0.00082],
#  ['fullbreakfast', 0.00082],
#  ['chickenmeat', 0.00082],
#  ['sundayroast', 0.00082],
#  ['standing', 0.00082],
#  ['joint', 0.00082],
#  ['headgear', 0.00082],
#  ['arm', 0.00082],
#  ['cool', 0.00082],
#  ['cap', 0.00082],
#  ['taste', 0.00082],
#  ['pastrychef', 0.00082],
#  ['ellipticaltrainer', 0.00082],
#  ['bedding', 0.00082],
#  ['reservoir', 0.00082],
#  ['flora', 0.00082],
#  ['pond', 0.00082],
#  ['fête', 0.00082],
#  ['historichouse', 0.00082],
#  ['brick', 0.00082],
#  ['heat', 0.00082],
#  ['fire', 0.00082],
#  ['flame', 0.00082],
#  ['smoke', 0.00082],
#  ['kingcrab', 0.00082],
#  ['crabmeat', 0.00082],
#  ['fish', 0.00082],
#  ['fishslice', 0.00082],
#  ['aiskacang', 0.00082],
#  ['sorbet', 0.00082],
#  ['vegetable', 0.00082],
#  ['kaiseki', 0.00082],
#  ['bowl', 0.00082],
#  ['ingredient', 0.00082],
#  ['redmeat', 0.00082],
#  ['matsusakabeef', 0.00082],
#  ['beef', 0.00082],
#  ['flesh', 0.00082],
#  ['wagyubeef', 0.00082],
#  ['lambandmutton', 0.00082],
#  ['tsukudani', 0.00082],
#  ['earlgreytea', 0.00082],
#  ['gravy', 0.00082],
#  ['fabadaasturiana', 0.00082],
#  ['viennasausage', 0.00082],
#  ['ginandtonic', 0.00082],
#  ['champagnestemware', 0.00082],
#  ['dip', 0.00082],
#  ['pannacotta', 0.00082],
#  ['fruit', 0.00082],
#  ['strawberry', 0.00082],
#  ['strawberries', 0.00082],
#  ['electricblue', 0.00082],
#  ['baybreeze', 0.00082],
#  ['orangedrink', 0.00082],
#  ['zombie', 0.00082],
#  ['cockle', 0.00082],
#  ['invertebrate', 0.00082],
#  ['spiral', 0.00082],
#  ['caffèmacchiato', 0.00082],
#  ['latte', 0.00082],
#  ['caféaulait', 0.00082],
#  ['cappuccino', 0.00082],
#  ['marocchino', 0.00082],
#  ['wienermelange', 0.00082],
#  ['cortado', 0.00082],
#  ['woowoo', 0.00082],
#  ['tintodeverano', 0.00082],
#  ['sangria', 0.00082],
#  ['dome', 0.00082],
#  ['library', 0.00082],
#  ['gimlet', 0.00082],
#  ['caipirinha', 0.00082],
#  ['lemonlime', 0.00082],
#  ['margarita', 0.00082]]

# %%
traveler_label_all_five
# Out:
# ['city',
#  'urbanarea',
#  'metropolitanarea',
#  'aerialphotography',
#  "bird'seyeview",
#  'metropolis',
#  'sky',
#  'building',
#  'skyline',
#  'suburb',
#  'buffet',
#  'food',
#  'wholefood',
#  'meal',
#  'cuisine',
#  'swimmingpool',
#  'resort',
#  'property',
#  'condominium',
#  'leisure',
#  'palmtree',
#  'arecales',
#  'hotel',
#  'realestate',
#  'mixeduse',
#  'room',
#  'property',
#  'livingroom',
#  'lobby',
#  'interiordesign',
#  'furniture',
#  'suite',
#  'table',
#  'floor',
#  'chair',
#  'resort',
#  'swimmingpool',
#  'mixeduse',
#  'arecales',
#  'palmtree',
#  'city',
#  'metropolitanarea',
#  'tree',
#  'tourism',
#  'condominium',
#  'landmark',
#  'city',
#  'classicalarchitecture',
#  'historicsite',
#  'building',
#  'palace',
#  'sky',
#  'touristattraction',
#  'metropolis',
#  'plaza',
#  'metropolitanarea',
#  'city',
#  'landmark',
#  'urbanarea',
#  'metropolis',
#  'plaza',
#  'building',
#  'skyline',
#  'skyscraper',
#  'cityscape',
#  'landmark',
#  'metropolitanarea',
#  'sky',
#  'tree',
#  'city',
#  'building',
#  'plant',
#  'grass',
#  'arecales',
#  'outdoorstructure',
#  'sky',
#  'city',
#  'urbanarea',
#  'metropolitanarea',
#  'cityscape',
#  'condominium',
#  'cloud',
#  'building',
#  'metropolis',
#  'daytime',
#  'arecales',
#  'palmtree',
#  'tree',
#  'condominium',
#  'hotel',
#  'building',
#  'plant',
#  'resort',
#  'realestate',
#  'touristattraction',
#  'night',
#  'lighting',
#  'world',
#  'festival',
#  'space',
#  'computerwallpaper',
#  'midnight',
#  'ceiling',
#  'room',
#  'interiordesign',
#  'wall',
#  'suite',
#  'bedframe',
#  'bedroom',
#  'livingroom',
#  'windowcovering',
#  'hotel',
#  'water',
#  'leisure',
#  'swimmingpool',
#  'resort',
#  'tree',
#  'vacation',
#  'waterpark',
#  'tropics',
#  'sky',
#  'lagoon',
#  'room',
#  'interiordesign',
#  'bedframe',
#  'wall',
#  'furniture',
#  'ceiling',
#  'bedroom',
#  'bed',
#  'suite',
#  'mattress',
#  'metropolitanarea',
#  'landmark',
#  'city',
#  'urbanarea',
#  'metropolis',
#  'palace',
#  'plaza',
#  'skyscraper',
#  'building',
#  'sky',
#  'condominium',
#  'building',
#  'hotel',
#  'resort',
#  'water',
#  'roof',
#  'apartment',
#  'tree',
#  'leisure',
#  'light',
#  'lighting',
#  'swimmingpool',
#  'functionhall',
#  'lobby',
#  'leisurecentre',
#  'hotel',
#  'condominium',
#  'resort',
#  'room',
#  'suite',
#  'interiordesign',
#  'wall',
#  'hotel',
#  'window',
#  'ceiling',
#  'realestate',
#  'bedroom',
#  'floor',
#  'swimmingpool',
#  'resort',
#  'water',
#  'leisure',
#  'property',
#  'resorttown',
#  'arecales',
#  'reflection',
#  'palmtree',
#  'vacation',
#  'swimmingpool',
#  'resort',
#  'leisure',
#  'property',
#  'resorttown',
#  'palmtree',
#  'arecales',
#  'water',
#  'vacation',
#  'tourism',
#  'room',
#  'property',
#  'wall',
#  'interiordesign',
#  'bedframe',
#  'suite',
#  'realestate',
#  'bedroom',
#  'ceiling',
#  'hotel',
#  'sky',
#  'palmtree',
#  'arecales',
#  'tree',
#  'touristattraction',
#  'plant',
#  'building',
#  'tourism',
#  'city',
#  'resort',
#  'room',
#  'property',
#  'ceiling',
#  'wall',
#  'architecture',
#  'interiordesign',
#  'home',
#  'floor',
#  'suite',
#  'realestate',
#  'livingroom',
#  'room',
#  'property',
#  'interiordesign',
#  'lobby',
#  'furniture',
#  'realestate',
#  'suite',
#  'table',
#  'couch',
#  'metropolitanarea',
#  'landmark',
#  'city',
#  'metropolis',
#  'cityscape',
#  'tower',
#  'building',
#  'touristattraction',
#  'condominium',
#  'tourism',
#  'resort',
#  'property',
#  'swimmingpool',
#  'arecales',
#  'leisure',
#  'palmtree',
#  'estate',
#  'realestate',
#  'hacienda',
#  'tree',
#  'resort',
#  'swimmingpool',
#  'property',
#  'leisure',
#  'water',
#  'palmtree',
#  'arecales',
#  'realestate',
#  'resorttown',
#  'tree',
#  'room',
#  'interiordesign',
#  'suite',
#  'livingroom',
#  'realestate',
#  'condominium',
#  'ceiling',
#  'lobby',
#  'window',
#  'apartment',
#  'room',
#  'property',
#  'ceiling',
#  'suite',
#  'interiordesign',
#  'wall',
#  'hotel',
#  'window',
#  'realestate',
#  'windowtreatment',
#  'property',
#  'room',
#  'wall',
#  'window',
#  'suite',
#  'condominium',
#  'interiordesign',
#  'balcony',
#  'realestate',
#  'apartment',
#  'metropolitanarea',
#  'urbanarea',
#  'city',
#  'metropolis',
#  'landmark',
#  'cityscape',
#  "bird'seyeview",
#  'tower',
#  'building',
#  'skyscraper',
#  'room',
#  'interiordesign',
#  'ceiling',
#  'lobby',
#  'restaurant',
#  'flooring',
#  'suite',
#  'swimmingpool',
#  'resort',
#  'leisure',
#  'sunlounger',
#  'outdoorfurniture',
#  'condominium',
#  'sea',
#  'vacation',
#  'beach',
#  'room',
#  'property',
#  'interiordesign',
#  'ceiling',
#  'suite',
#  'bedframe',
#  'realestate',
#  'hotel',
#  'bedroom',
#  'table',
#  'furniture',
#  'aerialphotography',
#  'city',
#  'urbanarea',
#  "bird'seyeview",
#  'resort',
#  'leisure',
#  'resorttown',
#  'metropolitanarea',
#  'recreation',
#  'condominium',
#  'dessert',
#  'food',
#  'macaroon',
#  'cookiesandcrackers',
#  'baking',
#  'dish',
#  'fingerfood',
#  'cookie',
#  'snack',
#  'room',
#  'suite',
#  'interiordesign',
#  'hotel',
#  'ceiling',
#  'comfort',
#  'landmark',
#  'touristattraction',
#  'plaza',
#  'sky',
#  'city',
#  'palace',
#  'tourism',
#  'building',
#  'outdoorstructure',
#  'waterfeature',
#  'swimmingpool',
#  'aerialphotography',
#  'water',
#  'leisure',
#  'resorttown',
#  "bird'seyeview",
#  'resort',
#  'tourism',
#  'waterresources',
#  'waterpark',
#  'metropolitanarea',
#  'landmark',
#  'city',
#  'metropolis',
#  'urbanarea',
#  'touristattraction',
#  'cityscape',
#  'building',
#  'tower',
#  'plaza',
#  'metropolitanarea',
#  'city',
#  'urbanarea',
#  'metropolis',
#  'plaza',
#  'building',
#  'townsquare',
#  'cityscape',
#  'mixeduse',
#  'downtown',
#  'room',
#  'suite',
#  'ceiling',
#  'interiordesign',
#  'hotel',
#  'landmark',
#  'city',
#  'urbanarea',
#  'metropolitanarea',
#  'metropolis',
#  'building',
#  'plaza',
#  'townsquare',
#  'palace',
#  'ceiling',
#  'room',
#  'interiordesign',
#  'livingroom',
#  'wall',
#  'lobby',
#  'suite',
#  'conferencehall',
#  'leisure',
#  'waterpark',
#  'swimmingpool',
#  'fun',
#  'amusementpark',
#  'vacation',
#  'water',
#  'leisurecentre',
#  'recreation',
#  'resort',
#  'swimmingpool',
#  'leisure',
#  'resort',
#  'water',
#  'leisurecentre',
#  'vacation',
#  'recreation',
#  'tourism',
#  'hotel',
#  'condominium',
#  'metropolitanarea',
#  'landmark',
#  'city',
#  'urbanarea',
#  'metropolis',
#  'building',
#  'plaza',
#  'classicalarchitecture',
#  'historicsite',
#  'palace',
#  'room',
#  'suite',
#  'interiordesign',
#  'realestate',
#  'hotel',
#  'lobby',
#  'interiordesign',
#  'shoppingmall',
#  'ceiling',
#  'room',
#  'property',
#  'suite',
#  'bedframe',
#  'bedroom',
#  'interiordesign',
#  'hotel',
#  'realestate',
#  'ceiling',
#  'landmark',
#  'city',
#  'metropolitanarea',
#  'metropolis',
#  'urbanarea',
#  'historicsite',
#  'building',
#  'plaza',
#  'touristattraction',
#  'palace',
#  'room',
#  'interiordesign',
#  'suite',
#  'bedframe',
#  'ceiling',
#  'bedroom',
#  'furniture',
#  'hotel',
#  'flooring',
#  'room',
#  'realestate',
#  'interiordesign',
#  'suite',
#  'hotel',
#  'bedroom',
#  'metropolitanarea',
#  'landmark',
#  'city',
#  'metropolis',
#  'building',
#  'sky',
#  'touristattraction',
#  'plaza',
#  'palace',
#  'towerblock',
#  'floor',
#  'room',
#  'property',
#  'flooring',
#  'suite',
#  'interiordesign',
#  'woodflooring',
#  'tile',
#  'livingroom',
#  'hardwood',
#  'room',
#  'bedframe',
#  'property',
#  'bedroom',
#  'suite',
#  'bed',
#  'furniture',
#  'ceiling',
#  'interiordesign',
#  'floor',
#  'metropolitanarea',
#  'landmark',
#  'city',
#  'metropolis',
#  'cityscape',
#  'sky',
#  'plaza',
#  'building',
#  'touristattraction',
#  'skyscraper',
#  'room',
#  'interiordesign',
#  'ceiling',
#  'architecture',
#  'wall',
#  'floor',
#  'lobby',
#  'apartment',
#  'realestate',
#  'suite',
#  'city',
#  'urbanarea',
#  "bird'seyeview",
#  'metropolitanarea',
#  'aerialphotography',
#  'metropolis',
#  'building',
#  'skyline',
#  'suburb',
#  'metropolitanarea',
#  'city',
#  'urbanarea',
#  'landmark',
#  'metropolis',
#  'cityscape',
#  'building',
#  'plaza',
#  'townsquare',
#  'sky',
#  'room',
#  'bedframe',
#  'suite',
#  'mattress',
#  'interiordesign',
#  'hotel',
#  'bed',
#  'floor',
#  'bedroom',
#  'room',
#  'furniture',
#  'bedframe',
#  'interiordesign',
#  'bed',
#  'flooring',
#  'wood',
#  'bedroom',
#  'suite',
#  'breakfast',
#  'brunch',
#  'meal',
#  'table',
#  'food',
#  'interiordesign',
#  'dessert',
#  'metropolitanarea',
#  'city',
#  'landmark',
#  'urbanarea',
#  'metropolis',
#  'plaza',
#  'cityscape',
#  'building',
#  'skyscraper',
#  'sky',
#  'room',
#  'ceiling',
#  'wall',
#  'interiordesign',
#  'suite',
#  'hotel',
#  'window',
#  'bedframe',
#  'home',
#  'bedroom',
#  'shoppingmall',
#  'glass',
#  'lobby',
#  'retail',
#  'interiordesign',
#  'swimmingpool',
#  'water',
#  'leisure',
#  'waterresources',
#  'waterpark',
#  'watercourse',
#  'waterfeature',
#  'chute',
#  'tree',
#  'river',
#  'property',
#  'room',
#  'interiordesign',
#  'livingroom',
#  'suite',
#  'couch',
#  'furniture',
#  'table',
#  'realestate',
#  'floor',
#  'metropolitanarea',
#  'city',
#  'landmark',
#  'metropolis',
#  'urbanarea',
#  'sky',
#  'cityscape',
#  'touristattraction',
#  'plaza',
#  'daytime',
#  'property',
#  'room',
#  'ceiling',
#  'interiordesign',
#  'wall',
#  'suite',
#  'lighting',
#  'realestate',
#  'bedroom',
#  'window',
#  'room',
#  'property',
#  'suite',
#  'ceiling',
#  'interiordesign',
#  'hotel',
#  'realestate',
#  'window',
#  'bedroom',
#  "bird'seyeview",
#  'aerialphotography',
#  'urbanarea',
#  'city',
#  'metropolitanarea',
#  'urbandesign',
#  'leisure',
#  'condominium',
#  'recreation',
#  'amusementpark',
#  'landmark',
#  'city',
#  'sky',
#  'metropolitanarea',
#  'metropolis',
#  'urbanarea',
#  'water',
#  'cityscape',
#  'touristattraction',
#  'building',
#  'room',
#  'wall',
#  'interiordesign',
#  'bedframe',
#  'ceiling',
#  'floor',
#  'bed',
#  'furniture',
#  'bedroom',
#  'suite',
#  'metropolitanarea',
#  'city',
#  'urbanarea',
#  'metropolis',
#  'cityscape',
#  'landmark',
#  "bird'seyeview",
#  'skyscraper',
#  'towerblock',
#  'aerialphotography',
#  'cuisine',
#  'food',
#  'dish',
#  'dimsum',
#  'chinesefood',
#  'meal',
#  'asianfood',
#  'vegetarianfood',
#  'breakfast',
#  'recipe',
#  'water',
#  'swimmingpool',
#  'leisure',
#  'waterresources',
#  'waterpark',
#  'waterfeature',
#  'resort',
#  'sea',
#  'lagoon',
#  'watercourse',
#  'room',
#  'ceiling',
#  'interiordesign',
#  'suite',
#  'hotel',
#  'floor',
#  'window',
#  'flooring',
#  'room',
#  'ceiling',
#  'property',
#  'interiordesign',
#  'suite',
#  'wall',
#  'window',
#  'hotel',
#  'windowtreatment',
#  'curtain',
#  'room',
#  'property',
#  'suite',
#  'bedframe',
#  'bedroom',
#  'interiordesign',
#  'ceiling',
#  'hotel',
#  'bed',
#  'furniture',
#  'flower',
#  'interiordesign',
#  'glass',
#  'plant',
#  'room',
#  'ceiling',
#  'interiordesign',
#  'hotel',
#  'suite',
#  'window',
#  'realestate',
#  'windowtreatment',
#  'condominium',
#  'room',
#  'property',
#  'suite',
#  'interiordesign',
#  'realestate',
#  'condominium',
#  'hotel',
#  'window',
#  'penthouseapartment',
#  'room',
#  'table',
#  'interiordesign',
#  'furniture',
#  'suite',
#  'restaurant',
#  'metropolis',
#  'symmetry',
#  'lobby',
#  'building',
#  'room',
#  'property',
#  'bedframe',
#  'suite',
#  'hotel',
#  'bedroom',
#  'bed',
#  'interiordesign',
#  'mattress',
#  'ceiling',
#  'landmark',
#  'night',
#  'metropolis',
#  'metropolitanarea',
#  'city',
#  'touristattraction',
#  'lighting',
#  'downtown',
#  'cityscape',
#  'sky',
#  'room',
#  'property',
#  'suite',
#  'interiordesign',
#  'ceiling',
#  'bedroom',
#  'hotel',
#  'realestate',
#  'bedframe',
#  'floor',
#  'room',
#  'ceiling',
#  'suite',
#  'interiordesign',
#  'wall',
#  'hotel',
#  'floor',
#  'realestate',
#  'window',
#  'flooring',
#  'room',
#  'interiordesign',
#  'suite',
#  'livingroom',
#  'lobby',
#  'ceiling',
#  'realestate',
#  'apartment',
#  'landmark',
#  'metropolitanarea',
#  'city',
#  'metropolis',
#  'sky',
#  'touristattraction',
#  'tourism',
#  'plaza',
#  'cityscape',
#  'palace',
#  'room',
#  'suite',
#  'interiordesign',
#  'hotel',
#  'ceiling',
#  'realestate',
#  'window',
#  'room',
#  'livingroom',
#  'interiordesign',
#  'ceiling',
#  'wall',
#  'lobby',
#  'suite',
#  'realestate',
#  'home',
#  'christmasdecoration',
#  'christmas',
#  'christmasornament',
#  'decor',
#  'tree',
#  'holiday',
#  'fête',
#  'christmastree',
#  'event',
#  'livingroom',
#  'furniture',
#  'table',
#  'room',
#  'interiordesign',
#  'floor',
#  'coffeetable',
#  'couch',
#  'flooring',
#  'suite',
#  'city',
#  'metropolitanarea',
#  'urbanarea',
#  'skyline',
#  'cityscape',
#  'metropolis',
#  'sky',
#  'downtown',
#  'daytime',
#  'towerblock',
#  'room',
#  'property',
#  'lobby',
#  'interiordesign',
#  'realestate',
#  'ceiling',
#  'suite',
#  'livingroom',
#  'window',
#  'condominium',
#  'room',
#  'suite',
#  'bedframe',
#  'hotel',
#  'mattress',
#  'room',
#  'suite',
#  'floor',
#  'ceiling',
#  'wall',
#  'interiordesign',
#  'flooring',
#  'bedframe',
#  'hotel',
#  'woodflooring',
#  'room',
#  'suite',
#  'ceiling',
#  'interiordesign',
#  'floor',
#  'flooring',
#  'hotel',
#  'realestate',
#  'window',
#  'lobby',
#  'room',
#  'property',
#  'bedframe',
#  'suite',
#  'hotel',
#  'bedroom',
#  'realestate',
#  'interiordesign',
#  'mattress',
#  'bed',
#  'resort',
#  'tree',
#  'palmtree',
#  'arecales',
#  'swimmingpool',
#  'water',
#  'leisure',
#  'tropics',
#  'sky',
#  'plant',
#  'night',
#  'landmark',
#  'metropolis',
#  'city',
#  'metropolitanarea',
#  'cityscape',
#  'touristattraction',
#  'downtown',
#  'building',
#  'sky',
#  'resort',
#  'swimmingpool',
#  'leisure',
#  'resorttown',
#  'tourism',
#  'waterresources',
#  'aerialphotography',
#  'water',
#  'tree',
#  'waterpark',
#  'room',
#  'livingroom',
#  'ceiling',
#  'interiordesign',
#  'suite',
#  'windowcovering',
#  'window',
#  'realestate',
#  'windowtreatment',
#  'lobby',
#  'water',
#  'swimmingpool',
#  'nature',
#  'leisure',
#  'resort',
#  'tropics',
#  'tree',
#  'vacation',
#  'palmtree',
#  'waterpark',
#  'metropolitanarea',
#  'urbanarea',
#  'city',
#  "bird'seyeview",
#  'metropolis',
#  'aerialphotography',
#  'cityscape',
#  'mixeduse',
#  'urbandesign',
#  'building',
#  'room',
#  'ceiling',
#  'suite',
#  'interiordesign',
#  'hotel',
#  'realestate',
#  'floor',
#  'tree',
#  'plant',
#  'arecales',
#  'swimmingpool',
#  'property',
#  'palmtree',
#  'resort',
#  'water',
#  'condominium',
#  'leisure',
#  ...]

# %%
print (stat_five[:50])
print ('==========================================================================================')
print (stat_four[:50])
print ('==========================================================================================')
print (stat_three[:50])
print ('==========================================================================================')
print (stat_two[:50])
